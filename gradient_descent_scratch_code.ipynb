# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
X,y = make_regression(n_samples=50, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=20)

# %%
plt.scatter(X,y)

# %%
reg = LinearRegression()

# %%
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([43.21914276])

# %%
reg.intercept_
# Out:
# -1.2480142419822955

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red')

# %%
class GDregressor:
    def __init__(self,lr,epochs):
        self.m = -200
        self.b = -120 
        self.lr = lr 
        self.epochs = epochs 

    def fit(self,X,y):
        for i in range(self.epochs):
            loss_slope_1 = -2*np.sum(y-self.m*X.ravel()-self.b)
            self.b = self.b-self.lr*loss_slope_1
            loss_slope_2 = -2*np.sum((y-self.m*X.ravel()-self.b)*X.ravel())
            self.m = self.m - self.lr*loss_slope_2

    def intercept(self):
        print(self.b) 

    def slope(self):
        print(self.m)

# %%
gd = GDregressor(0.001,1000)

# %%
gd.fit(X,y)

# %%
gd.intercept()
# Out:
# -1.2480142419822986

# %%
gd.slope()
# Out:
# 43.21914276299744

# %%
X.ravel().shape
# Out:
# (50,)
